# %%
print("this is my first python program")
# Out:
# this is my first python program

# %%
# This symbol is used to comment line
print('hello')
# Out:
# hello

# %%
# For multiple line comments we used thriple quotes
"""
hahka
akkjklaj
lanlnlan
na,,nllna
lkjaljla
mlam"""
# Out:
# '\nhahka\nakkjklaj\nlanlnlan\nna,,nllna\nlkjaljla\nmlam'

# %% [markdown]
# VARIABLES

# %%
a = 84

# %%
a
# Out:
# 84

# %%
type(a)
# Out:
# int

# %%
b = 'abhinay'

# %%
b
# Out:
# 'abhinay'

# %%
type(b)
# Out:
# str

# %%
print(a,b)
# Out:
# 84 abhinay

# %%
print(a,b,"helpp")
# Out:
# 84 abhinay helpp

# %%
a , b , c = 78 , 'this is me', "4eree"

# %%
print(a,b,c)
# Out:
# 78 this is me 4eree

# %%
a,b,c
# Out:
# (78, 'this is me', '4eree')

# %%
type(c)
# Out:
# str

# %%
print(True + True + True + False + True)
print (False - True + True)
# Out:
# 4
# 0

# %%
#complex no.
n = 45 + 4j
# j is the only notation used for complex no.

# %%
 n
# Out:
# (45+4j)

# %%
type(n)
# Out:
# complex

# %%
n.real
# Out:
# 45.0

# %%
n.imag
# Out:
# 4.0

# %%
# Typecasting -> str() 
str(1) + 'abhi'
# Out:
# '1abhi'

# %%
a = 1 + 1.0

# %%
type(a)
# Out:
# float

# %%
'abhi' * 5
# Out:
# 'abhiabhiabhiabhiabhi'

# %%
s = input()
# Out:
# Heloo my name is singh

# %%
s
# Out:
# 'Heloo my name is singh'

# %%
a = int(input("a"))
b = int(input("b"))
c = int(input("c"))
# Out:
# a45
# b56
# c34

# %%
a,b,c
# Out:
# (45, 56, 34)

# %%
o = a+b/c

# %%
o
# Out:
# 46.64705882352941

# %%
o1 = o + 78 + 6j

# %%
str(o1) + "abhi"
# Out:
# '(124.64705882352942+6j)abhi'

# %%
a = int(input('Enter a number : '))
if a < 34 :
    print("data input is lesser then 34 and i am fine with it.")
# Out:
# Enter a number : 5
# data input is lesser then 34 and i am fine with it.

# %%
a = int(input('Enter a number : '))
if a < 34 :
    pass
print("data input is lesser then 34 and i am fine with it.")
# Out:
# Enter a number : 65
# data input is lesser then 34 and i am fine with it.

# %%
a = int(input('Enter a number : '))
if a < 34 :
    print("data input is lesser then 34 and i am fine with it.")
else:
    print("user input is not lesser then 34")
# Out:
# Enter a number : 56
# user input is not lesser then 34

# %%
a = int(input('Enter a number : '))
if a < 34 :
    print("data input is lesser then 34 and i am fine with it.")
elif a<100:
    print("my data is lesser then 100")
else:
    print("user input is not lesser then 34")
# Out:
# Enter a number : 64
# my data is lesser then 100

# %%
 salary = int(input("enter your salary : "))
if salary > 1000:
    print("i will buy a car")
elif salary > 500:
    print("i will go for bike")
elif salary > 100:
    print("i will not buy anything")
else :
    print("i will go for savings")
# Out:
# enter your salary : 200
# i will not buy anything

# %%
2 + 4
# Out:
# 6

# %%
a = int(input("this is my var a "))
b = int(input("this is my var b "))
c = int(input("this is my var c "))
# Out:
# this is my var a 45
# this is my var b 54
# this is my var c 66

# %%
a,b,c
# Out:
# (45, 54, 66)
